# %%
import google.generativeai as genai
genai.configure(api_key='ADD API KEY')

for m in genai.list_models():
  if 'generateContent' in m.supported_generation_methods:
    print(m.name)
# Out:
# models/gemini-1.0-pro-latest
# models/gemini-1.0-pro
# models/gemini-pro
# models/gemini-1.0-pro-001
# models/gemini-1.0-pro-vision-latest
# models/gemini-pro-vision
# models/gemini-1.5-pro-latest
# models/gemini-1.5-pro-001
# models/gemini-1.5-pro
# models/gemini-1.5-pro-exp-0801
# models/gemini-1.5-flash-latest
# models/gemini-1.5-flash-001
# models/gemini-1.5-flash
# models/gemini-1.5-flash-001-tuning

# %%
model = genai.GenerativeModel('gemini-pro')

# %%
# %%time

import os
import pathlib
import json

# Assuming files_path is defined and is a Path object
files_path = pathlib.Path('/Users/moutasemhome/Human-vs.-Synthetic-Datasets-Advancing-Niche-Model-Training-for-qa/data/torch_code_base.json/step_1_torch_repo/full_codebase')
print(f"Processing files in: {files_path.absolute()}")

# Ensure the output directory exists
output_dir = pathlib.Path('/Users/moutasemhome/Human-vs.-Synthetic-Datasets-Advancing-Niche-Model-Training-for-qa/data/step_3_generated_qa')
output_dir.mkdir(parents=True, exist_ok=True)
print(f"Output will be saved to: {output_dir.absolute()}")

# Track processed files
processed_files_tracker = output_dir / 'processed_files.txt'
if not processed_files_tracker.exists():
    processed_files_tracker.touch()
with open(processed_files_tracker, 'r') as f:
    processed_files = set(f.read().splitlines())

total_files = sum(1 for _ in files_path.glob('*.json'))
print(f"Total files to process: {total_files}")
print(f"Already processed files: {len(processed_files)}")
files_left = total_files - len(processed_files)
print(f"Files left to process: {files_left}")

file_processed = False
failed_responses = {}

for file_path in files_path.glob('*.json'):
    if file_path.name in processed_files:
        continue  # Skip this file since it's already been processed

    print(f"Processing file: {file_path}")
    with open(file_path, 'r', encoding='utf-8') as file:
        # Load JSON content
        json_content = json.load(file)
        content = json_content['content']
    
    # Prepare the prompt based on the content type
    content_type = json_content['type']
    
    prompt = f"""Please generate a series of detailed questions and answers in clean JSON format, suitable for direct parsing with json.loads, that would challenge a developer or deep learning engineer's understanding of the following content about pytorch and deep learning. The focus areas include:
    
    - Implementation Nuances: Specific code choices, their potential trade-offs, and alternative implementations.
    - Theoretical Underpinnings: Conceptual knowledge behind algorithms and techniques used in the content.
    - Practical Implications: Real-world scenarios, edge cases, and failure modes relevant to the code or models.
    - Efficiency and Best Practices: Strategies for optimizing PyTorch code for better performance and adherence to best practices.
    
    The content for analysis is: {content}
    
    Guidelines for question and answer generation:
    - Clear and Specific: Questions must directly relate to the content, with relevant code snippets included for clarity.
    - Insightful Answers: Provide deep insights, efficiency tips, and potential improvements in the answers.
    - Standalone Value: Each QA pair must stand alone in value, understandable without the context of other pairs.
    - Clean JSON Format: Structure the output as a JSON array of objects, each with 'question' and 'answer' keys, ensuring the format is correct for json.loads parsing.
    
    Illustrative Examples:
    
    [
        {{
            "question": "Why is ReLU used as the activation function in the given convolutional neural network layer implementation?",
            "answer": "ReLU is chosen for its computational efficiency and ability to mitigate vanishing gradients. While tanh might offer smoother gradients, it can be computationally slower and still susceptible to saturation issues. Consider the task and dataset characteristics when experimenting with alternatives."
        }},
        {{
            "question": "What advantages does creating a custom dataset class in PyTorch offer over using predefined datasets, and how does the DataLoader interface enhance batch processing?",
            "answer": "Creating a custom dataset class allows for greater flexibility in preprocessing and handling data that may not fit the standard formats of predefined datasets. Utilizing the DataLoader interface enables efficient batch processing, automatic batching, shuffling, and parallel data loading. These features are crucial for handling large datasets and optimizing the training process."
        }},
        {{
            "question": "Explain the significance of the .to(device) method in PyTorch code, especially in the context of model training across different hardware.",
            "answer": "The .to(device) method allows for device-agnostic coding by dynamically allocating tensors or models to the available hardware, optimizing computational efficiency and leveraging GPU acceleration. This significantly speeds up model training and inference times by utilizing parallel processing capabilities of GPUs."
        }},
        ...
    ]
    
    Please adhere to the JSON format meticulously, ensuring each object within the array follows the '{{"question": "", "answer": ""}}' structure, ready for immediate parsing and utilization in development environments."""

    
    try:
        # Placeholder for the model call and response handling
        response = model.generate_content(prompt).text

        print(f"Received response for {file_path.name}")

        response = model.generate_content(prompt).text

        print(f"Received response for {file_path.name}")
       

        # Extracting the file name without the .json extension for the output
        base_file_name = os.path.basename(file_path).rsplit('.', 1)[0]  # Removes the last extension
        output_file_path = output_dir / f'{base_file_name}_qa.txt'

        # Writing the response to the new file
        with open(output_file_path, 'w', encoding='utf-8') as output_file:
            output_file.write(response)


        # After successfully processing and saving:
        with open(processed_files_tracker, 'a') as f:
            f.write(f"{file_path.name}\n")  # Record this file as processed
        
        file_processed = True
        print(f"Output saved to: {output_file_path}")
    except Exception as e:
        print(f"Failed to process {file_path}: {e}")
        failed_responses[str(file_path)] = str(e)

if not file_processed:
    print("No files were processed. Check if the input directory exists and contains .json files.")

# Optionally, handle failed_responses here
if failed_responses:
    print("Some files failed to process:")
    for file_path, error in failed_responses.items():
        print(f"{file_path}: {error}")

# Update counts at the end
with open(processed_files_tracker, 'r') as f:
    processed_files = set(f.read().splitlines())
files_processed = len(processed_files)
files_left = total_files - files_processed
print(f"Total files processed: {files_processed}")
print(f"Files left to process: {files_left}")
# Out:
# Processing files in: /Users/moutasemhome/Human-vs.-Synthetic-Datasets-Advancing-Niche-Model-Training-for-qa/data/torch_code_base.json/step_1_torch_repo/full_codebase
# Output will be saved to: /Users/moutasemhome/Human-vs.-Synthetic-Datasets-Advancing-Niche-Model-Training-for-qa/data/step_3_generated_qa
# Total files to process: 2672
# Already processed files: 0
# Files left to process: 2672
# Processing file: /Users/moutasemhome/Human-vs.-Synthetic-Datasets-Advancing-Niche-Model-Training-for-qa/data/torch_code_base.json/step_1_torch_repo/full_codebase/test_python_dispatch.json
# Received response for test_python_dispatch.json
# Failed to process /Users/moutasemhome/Human-vs.-Synthetic-Datasets-Advancing-Niche-Model-Training-for-qa/data/torch_code_base.json/step_1_torch_repo/full_codebase/test_python_dispatch.json: 429 Resource has been exhausted (e.g. check quota).
# Processing file: /Users/moutasemhome/Human-vs.-Synthetic-Datasets-Advancing-Niche-Model-Training-for-qa/data/torch_code_base.json/step_1_torch_repo/full_codebase/faulty_agent_rpc_test.json
# Failed to process /Users/moutasemhome/Human-vs.-Synthetic-Datasets-Advancing-Niche-Model-Training-for-qa/data/torch_code_base.json/step_1_torch_repo/full_codebase/faulty_agent_rpc_test.json: 429 Resource has been exhausted (e.g. check quota).
# Processing file: /Users/moutasemhome/Human-vs.-Synthetic-Datasets-Advancing-Niche-Model-Training-for-qa/data/torch_code_base.json/step_1_torch_repo/full_codebase/common_quantization.json
# Failed to process /Users/moutasemhome/Human-vs.-Synthetic-Datasets-Advancing-Niche-Model-Training-for-qa/data/torch_code_base.json/step_1_torch_repo/full_codebase/common_quantization.json: 429 Resource has been exhausted (e.g. check quota).
# Processing file: /Users/moutasemhome/Human-vs.-Synthetic-Datasets-Advancing-Niche-Model-Training-for-qa/data/torch_code_base.json/step_1_torch_repo/full_codebase/signal.json
# Failed to process /Users/moutasemhome/Human-vs.-Synthetic-Datasets-Advancing-Niche-Model-Training-for-qa/data/torch_code_base.json/step_1_torch_repo/full_codebase/signal.json: 429 Resource has been exhausted (e.g. check quota).
# Processing file: /Users/moutasemhome/Human-vs.-Synthetic-Datasets-Advancing-Niche-Model-Training-for-qa/data/torch_code_base.json/step_1_torch_repo/full_codebase/reshard.json
# Failed to process /Users/moutasemhome/Human-vs.-Synthetic-Datasets-Advancing-Niche-Model-Training-for-qa/data/torch_code_base.json/step_1_torch_repo/full_codebase/reshard.json: 429 Resource has been exhausted (e.g. check quota).
# Processing file: /Users/moutasemhome/Human-vs.-Synthetic-Datasets-Advancing-Niche-Model-Training-for-qa/data/torch_code_base.json/step_1_torch_repo/full_codebase/test_fsdp_input.json
# Received response for test_fsdp_input.json
# Received response for test_fsdp_input.json
# Output saved to: /Users/moutasemhome/Human-vs.-Synthetic-Datasets-Advancing-Niche-Model-Training-for-qa/data/step_3_generated_qa/test_fsdp_input_qa.txt
# Processing file: /Users/moutasemhome/Human-vs.-Synthetic-Datasets-Advancing-Niche-Model-Training-for-qa/data/torch_code_base.json/step_1_torch_repo/full_codebase/test_common.json
# Failed to process /Users/moutasemhome/Human-vs.-Synthetic-Datasets-Advancing-Niche-Model-Training-for-qa/data/torch_code_base.json/step_1_torch_repo/full_codebase/test_common.json: 429 Resource has been exhausted (e.g. check quota).
# Processing file: /Users/moutasemhome/Human-vs.-Synthetic-Datasets-Advancing-Niche-Model-Training-for-qa/data/torch_code_base.json/step_1_torch_repo/full_codebase/pixelshuffle.json
# Failed to process /Users/moutasemhome/Human-vs.-Synthetic-Datasets-Advancing-Niche-Model-Training-for-qa/data/torch_code_base.json/step_1_torch_repo/full_codebase/pixelshuffle.json: 429 Resource has been exhausted (e.g. check quota).
# Processing file: /Users/moutasemhome/Human-vs.-Synthetic-Datasets-Advancing-Niche-Model-Training-for-qa/data/torch_code_base.json/step_1_torch_repo/full_codebase/unification_tools.json
# Failed to process /Users/moutasemhome/Human-vs.-Synthetic-Datasets-Advancing-Niche-Model-Training-for-qa/data/torch_code_base.json/step_1_torch_repo/full_codebase/unification_tools.json: 429 Resource has been exhausted (e.g. check quota).
# Processing file: /Users/moutasemhome/Human-vs.-Synthetic-Datasets-Advancing-Niche-Model-Training-for-qa/data/torch_code_base.json/step_1_torch_repo/full_codebase/cpp.json
# Failed to process /Users/moutasemhome/Human-vs.-Synthetic-Datasets-Advancing-Niche-Model-Training-for-qa/data/torch_code_base.json/step_1_torch_repo/full_codebase/cpp.json: 429 Resource has been exhausted (e.g. check quota).
# Processing file: /Users/moutasemhome/Human-vs.-Synthetic-Datasets-Advancing-Niche-Model-Training-for-qa/data/torch_code_base.json/step_1_torch_repo/full_codebase/parametrization.json
# Failed to process /Users/moutasemhome/Human-vs.-Synthetic-Datasets-Advancing-Niche-Model-Training-for-qa/data/torch_code_base.json/step_1_torch_repo/full_codebase/parametrization.json: 429 Resource has been exhausted (e.g. check quota).
# Processing file: /Users/moutasemhome/Human-vs.-Synthetic-Datasets-Advancing-Niche-Model-Training-for-qa/data/torch_code_base.json/step_1_torch_repo/full_codebase/etcd_store.json
# Failed to process /Users/moutasemhome/Human-vs.-Synthetic-Datasets-Advancing-Niche-Model-Training-for-qa/data/torch_code_base.json/step_1_torch_repo/full_codebase/etcd_store.json: 429 Resource has been exhausted (e.g. check quota).
# Processing file: /Users/moutasemhome/Human-vs.-Synthetic-Datasets-Advancing-Niche-Model-Training-for-qa/data/torch_code_base.json/step_1_torch_repo/full_codebase/gen_artifact.json
# Failed to process /Users/moutasemhome/Human-vs.-Synthetic-Datasets-Advancing-Niche-Model-Training-for-qa/data/torch_code_base.json/step_1_torch_repo/full_codebase/gen_artifact.json: 429 Resource has been exhausted (e.g. check quota).
# Processing file: /Users/moutasemhome/Human-vs.-Synthetic-Datasets-Advancing-Niche-Model-Training-for-qa/data/torch_code_base.json/step_1_torch_repo/full_codebase/generator.json
# Failed to process /Users/moutasemhome/Human-vs.-Synthetic-Datasets-Advancing-Niche-Model-Training-for-qa/data/torch_code_base.json/step_1_torch_repo/full_codebase/generator.json: 429 Resource has been exhausted (e.g. check quota).
# Processing file: /Users/moutasemhome/Human-vs.-Synthetic-Datasets-Advancing-Niche-Model-Training-for-qa/data/torch_code_base.json/step_1_torch_repo/full_codebase/test_module_containers.json
# Failed to process /Users/moutasemhome/Human-vs.-Synthetic-Datasets-Advancing-Niche-Model-Training-for-qa/data/torch_code_base.json/step_1_torch_repo/full_codebase/test_module_containers.json: 429 Resource has been exhausted (e.g. check quota).
# Processing file: /Users/moutasemhome/Human-vs.-Synthetic-Datasets-Advancing-Niche-Model-Training-for-qa/data/torch_code_base.json/step_1_torch_repo/full_codebase/build_bundled.json
# Failed to process /Users/moutasemhome/Human-vs.-Synthetic-Datasets-Advancing-Niche-Model-Training-for-qa/data/torch_code_base.json/step_1_torch_repo/full_codebase/build_bundled.json: 429 Resource has been exhausted (e.g. check quota).
# Processing file: /Users/moutasemhome/Human-vs.-Synthetic-Datasets-Advancing-Niche-Model-Training-for-qa/data/torch_code_base.json/step_1_torch_repo/full_codebase/test_index_tricks.json
# Failed to process /Users/moutasemhome/Human-vs.-Synthetic-Datasets-Advancing-Niche-Model-Training-for-qa/data/torch_code_base.json/step_1_torch_repo/full_codebase/test_index_tricks.json: 429 Resource has been exhausted (e.g. check quota).
# Processing file: /Users/moutasemhome/Human-vs.-Synthetic-Datasets-Advancing-Niche-Model-Training-for-qa/data/torch_code_base.json/step_1_torch_repo/full_codebase/test_operators.json
# Failed to process /Users/moutasemhome/Human-vs.-Synthetic-Datasets-Advancing-Niche-Model-Training-for-qa/data/torch_code_base.json/step_1_torch_repo/full_codebase/test_operators.json: 429 Resource has been exhausted (e.g. check quota).
# Processing file: /Users/moutasemhome/Human-vs.-Synthetic-Datasets-Advancing-Niche-Model-Training-for-qa/data/torch_code_base.json/step_1_torch_repo/full_codebase/merge_data.json
# Failed to process /Users/moutasemhome/Human-vs.-Synthetic-Datasets-Advancing-Niche-Model-Training-for-qa/data/torch_code_base.json/step_1_torch_repo/full_codebase/merge_data.json: 429 Resource has been exhausted (e.g. check quota).
# Processing file: /Users/moutasemhome/Human-vs.-Synthetic-Datasets-Advancing-Niche-Model-Training-for-qa/data/torch_code_base.json/step_1_torch_repo/full_codebase/_fx_passes.json
# Failed to process /Users/moutasemhome/Human-vs.-Synthetic-Datasets-Advancing-Niche-Model-Training-for-qa/data/torch_code_base.json/step_1_torch_repo/full_codebase/_fx_passes.json: 429 Resource has been exhausted (e.g. check quota).
# Processing file: /Users/moutasemhome/Human-vs.-Synthetic-Datasets-Advancing-Niche-Model-Training-for-qa/data/torch_code_base.json/step_1_torch_repo/full_codebase/test_numeric_suite_fx.json
# Failed to process /Users/moutasemhome/Human-vs.-Synthetic-Datasets-Advancing-Niche-Model-Training-for-qa/data/torch_code_base.json/step_1_torch_repo/full_codebase/test_numeric_suite_fx.json: 429 Resource has been exhausted (e.g. check quota).
# Processing file: /Users/moutasemhome/Human-vs.-Synthetic-Datasets-Advancing-Niche-Model-Training-for-qa/data/torch_code_base.json/step_1_torch_repo/full_codebase/test_minifier_isolate.json
# Failed to process /Users/moutasemhome/Human-vs.-Synthetic-Datasets-Advancing-Niche-Model-Training-for-qa/data/torch_code_base.json/step_1_torch_repo/full_codebase/test_minifier_isolate.json: 429 Resource has been exhausted (e.g. check quota).
# Processing file: /Users/moutasemhome/Human-vs.-Synthetic-Datasets-Advancing-Niche-Model-Training-for-qa/data/torch_code_base.json/step_1_torch_repo/full_codebase/benchmark_helper.json
# Failed to process /Users/moutasemhome/Human-vs.-Synthetic-Datasets-Advancing-Niche-Model-Training-for-qa/data/torch_code_base.json/step_1_torch_repo/full_codebase/benchmark_helper.json: 429 Resource has been exhausted (e.g. check quota).
# Processing file: /Users/moutasemhome/Human-vs.-Synthetic-Datasets-Advancing-Niche-Model-Training-for-qa/data/torch_code_base.json/step_1_torch_repo/full_codebase/tensor_constructors.json
# Failed to process /Users/moutasemhome/Human-vs.-Synthetic-Datasets-Advancing-Niche-Model-Training-for-qa/data/torch_code_base.json/step_1_torch_repo/full_codebase/tensor_constructors.json: 429 Resource has been exhausted (e.g. check quota).
# Processing file: /Users/moutasemhome/Human-vs.-Synthetic-Datasets-Advancing-Niche-Model-Training-for-qa/data/torch_code_base.json/step_1_torch_repo/full_codebase/test_scalar_ctors.json
# Failed to process /Users/moutasemhome/Human-vs.-Synthetic-Datasets-Advancing-Niche-Model-Training-for-qa/data/torch_code_base.json/step_1_torch_repo/full_codebase/test_scalar_ctors.json: 429 Resource has been exhausted (e.g. check quota).
# Processing file: /Users/moutasemhome/Human-vs.-Synthetic-Datasets-Advancing-Niche-Model-Training-for-qa/data/torch_code_base.json/step_1_torch_repo/full_codebase/test_cuda_expandable_segments.json
# Failed to process /Users/moutasemhome/Human-vs.-Synthetic-Datasets-Advancing-Niche-Model-Training-for-qa/data/torch_code_base.json/step_1_torch_repo/full_codebase/test_cuda_expandable_segments.json: 429 Resource has been exhausted (e.g. check quota).
# Processing file: /Users/moutasemhome/Human-vs.-Synthetic-Datasets-Advancing-Niche-Model-Training-for-qa/data/torch_code_base.json/step_1_torch_repo/full_codebase/adaptive.json
# Failed to process /Users/moutasemhome/Human-vs.-Synthetic-Datasets-Advancing-Niche-Model-Training-for-qa/data/torch_code_base.json/step_1_torch_repo/full_codebase/adaptive.json: 429 Resource has been exhausted (e.g. check quota).
# Processing file: /Users/moutasemhome/Human-vs.-Synthetic-Datasets-Advancing-Niche-Model-Training-for-qa/data/torch_code_base.json/step_1_torch_repo/full_codebase/_triton_ops_meta.json
# Failed to process /Users/moutasemhome/Human-vs.-Synthetic-Datasets-Advancing-Niche-Model-Training-for-qa/data/torch_code_base.json/step_1_torch_repo/full_codebase/_triton_ops_meta.json: 429 Resource has been exhausted (e.g. check quota).
# Processing file: /Users/moutasemhome/Human-vs.-Synthetic-Datasets-Advancing-Niche-Model-Training-for-qa/data/torch_code_base.json/step_1_torch_repo/full_codebase/fuse.json
# Failed to process /Users/moutasemhome/Human-vs.-Synthetic-Datasets-Advancing-Niche-Model-Training-for-qa/data/torch_code_base.json/step_1_torch_repo/full_codebase/fuse.json: 429 Resource has been exhausted (e.g. check quota).
# Processing file: /Users/moutasemhome/Human-vs.-Synthetic-Datasets-Advancing-Niche-Model-Training-for-qa/data/torch_code_base.json/step_1_torch_repo/full_codebase/mobile_optimizer.json
# Failed to process /Users/moutasemhome/Human-vs.-Synthetic-Datasets-Advancing-Niche-Model-Training-for-qa/data/torch_code_base.json/step_1_torch_repo/full_codebase/mobile_optimizer.json: 429 Resource has been exhausted (e.g. check quota).
# Processing file: /Users/moutasemhome/Human-vs.-Synthetic-Datasets-Advancing-Niche-Model-Training-for-qa/data/torch_code_base.json/step_1_torch_repo/full_codebase/powerSGD_hook.json
# Failed to process /Users/moutasemhome/Human-vs.-Synthetic-Datasets-Advancing-Niche-Model-Training-for-qa/data/torch_code_base.json/step_1_torch_repo/full_codebase/powerSGD_hook.json: 429 Resource has been exhausted (e.g. check quota).
# Processing file: /Users/moutasemhome/Human-vs.-Synthetic-Datasets-Advancing-Niche-Model-Training-for-qa/data/torch_code_base.json/step_1_torch_repo/full_codebase/gen_mobile_upgraders_constant.json
# Failed to process /Users/moutasemhome/Human-vs.-Synthetic-Datasets-Advancing-Niche-Model-Training-for-qa/data/torch_code_base.json/step_1_torch_repo/full_codebase/gen_mobile_upgraders_constant.json: 429 Resource has been exhausted (e.g. check quota).
# Processing file: /Users/moutasemhome/Human-vs.-Synthetic-Datasets-Advancing-Niche-Model-Training-for-qa/data/torch_code_base.json/step_1_torch_repo/full_codebase/test_deploy.json
# Failed to process /Users/moutasemhome/Human-vs.-Synthetic-Datasets-Advancing-Niche-Model-Training-for-qa/data/torch_code_base.json/step_1_torch_repo/full_codebase/test_deploy.json: 429 Resource has been exhausted (e.g. check quota).
# Processing file: /Users/moutasemhome/Human-vs.-Synthetic-Datasets-Advancing-Niche-Model-Training-for-qa/data/torch_code_base.json/step_1_torch_repo/full_codebase/file_based_local_timer_test.json
# Failed to process /Users/moutasemhome/Human-vs.-Synthetic-Datasets-Advancing-Niche-Model-Training-for-qa/data/torch_code_base.json/step_1_torch_repo/full_codebase/file_based_local_timer_test.json: 429 Resource has been exhausted (e.g. check quota).
# Processing file: /Users/moutasemhome/Human-vs.-Synthetic-Datasets-Advancing-Niche-Model-Training-for-qa/data/torch_code_base.json/step_1_torch_repo/full_codebase/group_batch_fusion.json
# Failed to process /Users/moutasemhome/Human-vs.-Synthetic-Datasets-Advancing-Niche-Model-Training-for-qa/data/torch_code_base.json/step_1_torch_repo/full_codebase/group_batch_fusion.json: 429 Resource has been exhausted (e.g. check quota).
# Processing file: /Users/moutasemhome/Human-vs.-Synthetic-Datasets-Advancing-Niche-Model-Training-for-qa/data/torch_code_base.json/step_1_torch_repo/full_codebase/tvm.json
# Failed to process /Users/moutasemhome/Human-vs.-Synthetic-Datasets-Advancing-Niche-Model-Training-for-qa/data/torch_code_base.json/step_1_torch_repo/full_codebase/tvm.json: 429 Resource has been exhausted (e.g. check quota).
# Processing file: /Users/moutasemhome/Human-vs.-Synthetic-Datasets-Advancing-Niche-Model-Training-for-qa/data/torch_code_base.json/step_1_torch_repo/full_codebase/redirects.json
# Failed to process /Users/moutasemhome/Human-vs.-Synthetic-Datasets-Advancing-Niche-Model-Training-for-qa/data/torch_code_base.json/step_1_torch_repo/full_codebase/redirects.json: 429 Resource has been exhausted (e.g. check quota).
# Processing file: /Users/moutasemhome/Human-vs.-Synthetic-Datasets-Advancing-Niche-Model-Training-for-qa/data/torch_code_base.json/step_1_torch_repo/full_codebase/constants.json
# Failed to process /Users/moutasemhome/Human-vs.-Synthetic-Datasets-Advancing-Niche-Model-Training-for-qa/data/torch_code_base.json/step_1_torch_repo/full_codebase/constants.json: 429 Resource has been exhausted (e.g. check quota).
# Processing file: /Users/moutasemhome/Human-vs.-Synthetic-Datasets-Advancing-Niche-Model-Training-for-qa/data/torch_code_base.json/step_1_torch_repo/full_codebase/per_sample_grads.json
# Failed to process /Users/moutasemhome/Human-vs.-Synthetic-Datasets-Advancing-Niche-Model-Training-for-qa/data/torch_code_base.json/step_1_torch_repo/full_codebase/per_sample_grads.json: 429 Resource has been exhausted (e.g. check quota).
# Processing file: /Users/moutasemhome/Human-vs.-Synthetic-Datasets-Advancing-Niche-Model-Training-for-qa/data/torch_code_base.json/step_1_torch_repo/full_codebase/test_fsdp_dsd.json
# Failed to process /Users/moutasemhome/Human-vs.-Synthetic-Datasets-Advancing-Niche-Model-Training-for-qa/data/torch_code_base.json/step_1_torch_repo/full_codebase/test_fsdp_dsd.json: 429 Resource has been exhausted (e.g. check quota).
# Processing file: /Users/moutasemhome/Human-vs.-Synthetic-Datasets-Advancing-Niche-Model-Training-for-qa/data/torch_code_base.json/step_1_torch_repo/full_codebase/codegen_device_driver.json
# Failed to process /Users/moutasemhome/Human-vs.-Synthetic-Datasets-Advancing-Niche-Model-Training-for-qa/data/torch_code_base.json/step_1_torch_repo/full_codebase/codegen_device_driver.json: 429 Resource has been exhausted (e.g. check quota).
# Processing file: /Users/moutasemhome/Human-vs.-Synthetic-Datasets-Advancing-Niche-Model-Training-for-qa/data/torch_code_base.json/step_1_torch_repo/full_codebase/checkpoint_wrapper.json
# Failed to process /Users/moutasemhome/Human-vs.-Synthetic-Datasets-Advancing-Niche-Model-Training-for-qa/data/torch_code_base.json/step_1_torch_repo/full_codebase/checkpoint_wrapper.json: 429 Resource has been exhausted (e.g. check quota).
# Processing file: /Users/moutasemhome/Human-vs.-Synthetic-Datasets-Advancing-Niche-Model-Training-for-qa/data/torch_code_base.json/step_1_torch_repo/full_codebase/data_sparsity.json
# Failed to process /Users/moutasemhome/Human-vs.-Synthetic-Datasets-Advancing-Niche-Model-Training-for-qa/data/torch_code_base.json/step_1_torch_repo/full_codebase/data_sparsity.json: 429 Resource has been exhausted (e.g. check quota).
# Processing file: /Users/moutasemhome/Human-vs.-Synthetic-Datasets-Advancing-Niche-Model-Training-for-qa/data/torch_code_base.json/step_1_torch_repo/full_codebase/funcname_cache.json
# Failed to process /Users/moutasemhome/Human-vs.-Synthetic-Datasets-Advancing-Niche-Model-Training-for-qa/data/torch_code_base.json/step_1_torch_repo/full_codebase/funcname_cache.json: 429 Resource has been exhausted (e.g. check quota).
# Processing file: /Users/moutasemhome/Human-vs.-Synthetic-Datasets-Advancing-Niche-Model-Training-for-qa/data/torch_code_base.json/step_1_torch_repo/full_codebase/bazel_linter.json
# Failed to process /Users/moutasemhome/Human-vs.-Synthetic-Datasets-Advancing-Niche-Model-Training-for-qa/data/torch_code_base.json/step_1_torch_repo/full_codebase/bazel_linter.json: 429 Resource has been exhausted (e.g. check quota).
# Processing file: /Users/moutasemhome/Human-vs.-Synthetic-Datasets-Advancing-Niche-Model-Training-for-qa/data/torch_code_base.json/step_1_torch_repo/full_codebase/test_ctx_manager.json
# Failed to process /Users/moutasemhome/Human-vs.-Synthetic-Datasets-Advancing-Niche-Model-Training-for-qa/data/torch_code_base.json/step_1_torch_repo/full_codebase/test_ctx_manager.json: 429 Resource has been exhausted (e.g. check quota).
# Processing file: /Users/moutasemhome/Human-vs.-Synthetic-Datasets-Advancing-Niche-Model-Training-for-qa/data/torch_code_base.json/step_1_torch_repo/full_codebase/_trace.json
# Failed to process /Users/moutasemhome/Human-vs.-Synthetic-Datasets-Advancing-Niche-Model-Training-for-qa/data/torch_code_base.json/step_1_torch_repo/full_codebase/_trace.json: 429 Resource has been exhausted (e.g. check quota).
# Processing file: /Users/moutasemhome/Human-vs.-Synthetic-Datasets-Advancing-Niche-Model-Training-for-qa/data/torch_code_base.json/step_1_torch_repo/full_codebase/common_modules.json
# Failed to process /Users/moutasemhome/Human-vs.-Synthetic-Datasets-Advancing-Niche-Model-Training-for-qa/data/torch_code_base.json/step_1_torch_repo/full_codebase/common_modules.json: 429 Resource has been exhausted (e.g. check quota).
# Processing file: /Users/moutasemhome/Human-vs.-Synthetic-Datasets-Advancing-Niche-Model-Training-for-qa/data/torch_code_base.json/step_1_torch_repo/full_codebase/test_snode_runtime.json
# Failed to process /Users/moutasemhome/Human-vs.-Synthetic-Datasets-Advancing-Niche-Model-Training-for-qa/data/torch_code_base.json/step_1_torch_repo/full_codebase/test_snode_runtime.json: 429 Resource has been exhausted (e.g. check quota).
# Processing file: /Users/moutasemhome/Human-vs.-Synthetic-Datasets-Advancing-Niche-Model-Training-for-qa/data/torch_code_base.json/step_1_torch_repo/full_codebase/common_mkldnn.json
# Failed to process /Users/moutasemhome/Human-vs.-Synthetic-Datasets-Advancing-Niche-Model-Training-for-qa/data/torch_code_base.json/step_1_torch_repo/full_codebase/common_mkldnn.json: 429 Resource has been exhausted (e.g. check quota).
# Processing file: /Users/moutasemhome/Human-vs.-Synthetic-Datasets-Advancing-Niche-Model-Training-for-qa/data/torch_code_base.json/step_1_torch_repo/full_codebase/unflatten.json
# Failed to process /Users/moutasemhome/Human-vs.-Synthetic-Datasets-Advancing-Niche-Model-Training-for-qa/data/torch_code_base.json/step_1_torch_repo/full_codebase/unflatten.json: 429 Resource has been exhausted (e.g. check quota).
# Processing file: /Users/moutasemhome/Human-vs.-Synthetic-Datasets-Advancing-Niche-Model-Training-for-qa/data/torch_code_base.json/step_1_torch_repo/full_codebase/_hook_iterator.json
# Failed to process /Users/moutasemhome/Human-vs.-Synthetic-Datasets-Advancing-Niche-Model-Training-for-qa/data/torch_code_base.json/step_1_torch_repo/full_codebase/_hook_iterator.json: 429 Resource has been exhausted (e.g. check quota).
# Processing file: /Users/moutasemhome/Human-vs.-Synthetic-Datasets-Advancing-Niche-Model-Training-for-qa/data/torch_code_base.json/step_1_torch_repo/full_codebase/cycling_iterator.json
# Failed to process /Users/moutasemhome/Human-vs.-Synthetic-Datasets-Advancing-Niche-Model-Training-for-qa/data/torch_code_base.json/step_1_torch_repo/full_codebase/cycling_iterator.json: 429 Resource has been exhausted (e.g. check quota).
# Processing file: /Users/moutasemhome/Human-vs.-Synthetic-Datasets-Advancing-Niche-Model-Training-for-qa/data/torch_code_base.json/step_1_torch_repo/full_codebase/echo3.json
# Failed to process /Users/moutasemhome/Human-vs.-Synthetic-Datasets-Advancing-Niche-Model-Training-for-qa/data/torch_code_base.json/step_1_torch_repo/full_codebase/echo3.json: 429 Resource has been exhausted (e.g. check quota).
# Processing file: /Users/moutasemhome/Human-vs.-Synthetic-Datasets-Advancing-Niche-Model-Training-for-qa/data/torch_code_base.json/step_1_torch_repo/full_codebase/auto_functionalize.json
# Failed to process /Users/moutasemhome/Human-vs.-Synthetic-Datasets-Advancing-Niche-Model-Training-for-qa/data/torch_code_base.json/step_1_torch_repo/full_codebase/auto_functionalize.json: 429 Resource has been exhausted (e.g. check quota).
# Processing file: /Users/moutasemhome/Human-vs.-Synthetic-Datasets-Advancing-Niche-Model-Training-for-qa/data/torch_code_base.json/step_1_torch_repo/full_codebase/metrics.json
# Failed to process /Users/moutasemhome/Human-vs.-Synthetic-Datasets-Advancing-Niche-Model-Training-for-qa/data/torch_code_base.json/step_1_torch_repo/full_codebase/metrics.json: 429 Resource has been exhausted (e.g. check quota).
# Processing file: /Users/moutasemhome/Human-vs.-Synthetic-Datasets-Advancing-Niche-Model-Training-for-qa/data/torch_code_base.json/step_1_torch_repo/full_codebase/transform_to_z3.json
# Failed to process /Users/moutasemhome/Human-vs.-Synthetic-Datasets-Advancing-Niche-Model-Training-for-qa/data/torch_code_base.json/step_1_torch_repo/full_codebase/transform_to_z3.json: 429 Resource has been exhausted (e.g. check quota).
# Processing file: /Users/moutasemhome/Human-vs.-Synthetic-Datasets-Advancing-Niche-Model-Training-for-qa/data/torch_code_base.json/step_1_torch_repo/full_codebase/fake_tensor.json
# Failed to process /Users/moutasemhome/Human-vs.-Synthetic-Datasets-Advancing-Niche-Model-Training-for-qa/data/torch_code_base.json/step_1_torch_repo/full_codebase/fake_tensor.json: 429 Resource has been exhausted (e.g. check quota).
# Processing file: /Users/moutasemhome/Human-vs.-Synthetic-Datasets-Advancing-Niche-Model-Training-for-qa/data/torch_code_base.json/step_1_torch_repo/full_codebase/modularization.json
# Failed to process /Users/moutasemhome/Human-vs.-Synthetic-Datasets-Advancing-Niche-Model-Training-for-qa/data/torch_code_base.json/step_1_torch_repo/full_codebase/modularization.json: 429 Resource has been exhausted (e.g. check quota).
# Processing file: /Users/moutasemhome/Human-vs.-Synthetic-Datasets-Advancing-Niche-Model-Training-for-qa/data/torch_code_base.json/step_1_torch_repo/full_codebase/test_selections.json
# Failed to process /Users/moutasemhome/Human-vs.-Synthetic-Datasets-Advancing-Niche-Model-Training-for-qa/data/torch_code_base.json/step_1_torch_repo/full_codebase/test_selections.json: 429 Resource has been exhausted (e.g. check quota).
# Processing file: /Users/moutasemhome/Human-vs.-Synthetic-Datasets-Advancing-Niche-Model-Training-for-qa/data/torch_code_base.json/step_1_torch_repo/full_codebase/dispatch_and_compile_graph.json
# Failed to process /Users/moutasemhome/Human-vs.-Synthetic-Datasets-Advancing-Niche-Model-Training-for-qa/data/torch_code_base.json/step_1_torch_repo/full_codebase/dispatch_and_compile_graph.json: 429 Resource has been exhausted (e.g. check quota).
# Processing file: /Users/moutasemhome/Human-vs.-Synthetic-Datasets-Advancing-Niche-Model-Training-for-qa/data/torch_code_base.json/step_1_torch_repo/full_codebase/test_fsdp_state_dict.json
# Failed to process /Users/moutasemhome/Human-vs.-Synthetic-Datasets-Advancing-Niche-Model-Training-for-qa/data/torch_code_base.json/step_1_torch_repo/full_codebase/test_fsdp_state_dict.json: 429 Resource has been exhausted (e.g. check quota).
# Processing file: /Users/moutasemhome/Human-vs.-Synthetic-Datasets-Advancing-Niche-Model-Training-for-qa/data/torch_code_base.json/step_1_torch_repo/full_codebase/cpp_utils.json
# Failed to process /Users/moutasemhome/Human-vs.-Synthetic-Datasets-Advancing-Niche-Model-Training-for-qa/data/torch_code_base.json/step_1_torch_repo/full_codebase/cpp_utils.json: 429 Resource has been exhausted (e.g. check quota).
# Processing file: /Users/moutasemhome/Human-vs.-Synthetic-Datasets-Advancing-Niche-Model-Training-for-qa/data/torch_code_base.json/step_1_torch_repo/full_codebase/class_method.json
# Failed to process /Users/moutasemhome/Human-vs.-Synthetic-Datasets-Advancing-Niche-Model-Training-for-qa/data/torch_code_base.json/step_1_torch_repo/full_codebase/class_method.json: 429 Resource has been exhausted (e.g. check quota).
# Processing file: /Users/moutasemhome/Human-vs.-Synthetic-Datasets-Advancing-Niche-Model-Training-for-qa/data/torch_code_base.json/step_1_torch_repo/full_codebase/fully_sharded_data_parallel.json
# Failed to process /Users/moutasemhome/Human-vs.-Synthetic-Datasets-Advancing-Niche-Model-Training-for-qa/data/torch_code_base.json/step_1_torch_repo/full_codebase/fully_sharded_data_parallel.json: 429 Resource has been exhausted (e.g. check quota).
# Processing file: /Users/moutasemhome/Human-vs.-Synthetic-Datasets-Advancing-Niche-Model-Training-for-qa/data/torch_code_base.json/step_1_torch_repo/full_codebase/benchmarks.json
# Failed to process /Users/moutasemhome/Human-vs.-Synthetic-Datasets-Advancing-Niche-Model-Training-for-qa/data/torch_code_base.json/step_1_torch_repo/full_codebase/benchmarks.json: 429 Resource has been exhausted (e.g. check quota).
# Processing file: /Users/moutasemhome/Human-vs.-Synthetic-Datasets-Advancing-Niche-Model-Training-for-qa/data/torch_code_base.json/step_1_torch_repo/full_codebase/test_sharder.json
# Failed to process /Users/moutasemhome/Human-vs.-Synthetic-Datasets-Advancing-Niche-Model-Training-for-qa/data/torch_code_base.json/step_1_torch_repo/full_codebase/test_sharder.json: 429 Resource has been exhausted (e.g. check quota).
# Processing file: /Users/moutasemhome/Human-vs.-Synthetic-Datasets-Advancing-Niche-Model-Training-for-qa/data/torch_code_base.json/step_1_torch_repo/full_codebase/_composable_state.json
# Failed to process /Users/moutasemhome/Human-vs.-Synthetic-Datasets-Advancing-Niche-Model-Training-for-qa/data/torch_code_base.json/step_1_torch_repo/full_codebase/_composable_state.json: 429 Resource has been exhausted (e.g. check quota).
# Processing file: /Users/moutasemhome/Human-vs.-Synthetic-Datasets-Advancing-Niche-Model-Training-for-qa/data/torch_code_base.json/step_1_torch_repo/full_codebase/binary_cmp.json
# Failed to process /Users/moutasemhome/Human-vs.-Synthetic-Datasets-Advancing-Niche-Model-Training-for-qa/data/torch_code_base.json/step_1_torch_repo/full_codebase/binary_cmp.json: 429 Resource has been exhausted (e.g. check quota).
# Processing file: /Users/moutasemhome/Human-vs.-Synthetic-Datasets-Advancing-Niche-Model-Training-for-qa/data/torch_code_base.json/step_1_torch_repo/full_codebase/test_planner.json
# Failed to process /Users/moutasemhome/Human-vs.-Synthetic-Datasets-Advancing-Niche-Model-Training-for-qa/data/torch_code_base.json/step_1_torch_repo/full_codebase/test_planner.json: 429 Resource has been exhausted (e.g. check quota).
# Processing file: /Users/moutasemhome/Human-vs.-Synthetic-Datasets-Advancing-Niche-Model-Training-for-qa/data/torch_code_base.json/step_1_torch_repo/full_codebase/test_selective_build.json
# Failed to process /Users/moutasemhome/Human-vs.-Synthetic-Datasets-Advancing-Niche-Model-Training-for-qa/data/torch_code_base.json/step_1_torch_repo/full_codebase/test_selective_build.json: 429 Resource has been exhausted (e.g. check quota).
# Processing file: /Users/moutasemhome/Human-vs.-Synthetic-Datasets-Advancing-Niche-Model-Training-for-qa/data/torch_code_base.json/step_1_torch_repo/full_codebase/_sfdp_pattern_5.json
# Failed to process /Users/moutasemhome/Human-vs.-Synthetic-Datasets-Advancing-Niche-Model-Training-for-qa/data/torch_code_base.json/step_1_torch_repo/full_codebase/_sfdp_pattern_5.json: 429 Resource has been exhausted (e.g. check quota).
# Processing file: /Users/moutasemhome/Human-vs.-Synthetic-Datasets-Advancing-Niche-Model-Training-for-qa/data/torch_code_base.json/step_1_torch_repo/full_codebase/test_save_load.json
# Failed to process /Users/moutasemhome/Human-vs.-Synthetic-Datasets-Advancing-Niche-Model-Training-for-qa/data/torch_code_base.json/step_1_torch_repo/full_codebase/test_save_load.json: 429 Resource has been exhausted (e.g. check quota).
# Processing file: /Users/moutasemhome/Human-vs.-Synthetic-Datasets-Advancing-Niche-Model-Training-for-qa/data/torch_code_base.json/step_1_torch_repo/full_codebase/test_minifier_common.json
# Failed to process /Users/moutasemhome/Human-vs.-Synthetic-Datasets-Advancing-Niche-Model-Training-for-qa/data/torch_code_base.json/step_1_torch_repo/full_codebase/test_minifier_common.json: 429 Resource has been exhausted (e.g. check quota).
# Processing file: /Users/moutasemhome/Human-vs.-Synthetic-Datasets-Advancing-Niche-Model-Training-for-qa/data/torch_code_base.json/step_1_torch_repo/full_codebase/test_extract_compiled_graph.json
# Failed to process /Users/moutasemhome/Human-vs.-Synthetic-Datasets-Advancing-Niche-Model-Training-for-qa/data/torch_code_base.json/step_1_torch_repo/full_codebase/test_extract_compiled_graph.json: 429 Resource has been exhausted (e.g. check quota).
# Processing file: /Users/moutasemhome/Human-vs.-Synthetic-Datasets-Advancing-Niche-Model-Training-for-qa/data/torch_code_base.json/step_1_torch_repo/full_codebase/test_config.json
# Failed to process /Users/moutasemhome/Human-vs.-Synthetic-Datasets-Advancing-Niche-Model-Training-for-qa/data/torch_code_base.json/step_1_torch_repo/full_codebase/test_config.json: 429 Resource has been exhausted (e.g. check quota).
# Processing file: /Users/moutasemhome/Human-vs.-Synthetic-Datasets-Advancing-Niche-Model-Training-for-qa/data/torch_code_base.json/step_1_torch_repo/full_codebase/_fsdp_state.json
# Failed to process /Users/moutasemhome/Human-vs.-Synthetic-Datasets-Advancing-Niche-Model-Training-for-qa/data/torch_code_base.json/step_1_torch_repo/full_codebase/_fsdp_state.json: 429 Resource has been exhausted (e.g. check quota).
# Processing file: /Users/moutasemhome/Human-vs.-Synthetic-Datasets-Advancing-Niche-Model-Training-for-qa/data/torch_code_base.json/step_1_torch_repo/full_codebase/test_torch_export_with_onnxruntime.json
# Failed to process /Users/moutasemhome/Human-vs.-Synthetic-Datasets-Advancing-Niche-Model-Training-for-qa/data/torch_code_base.json/step_1_torch_repo/full_codebase/test_torch_export_with_onnxruntime.json: 429 Resource has been exhausted (e.g. check quota).
# Processing file: /Users/moutasemhome/Human-vs.-Synthetic-Datasets-Advancing-Niche-Model-Training-for-qa/data/torch_code_base.json/step_1_torch_repo/full_codebase/_backward_state.json
# Failed to process /Users/moutasemhome/Human-vs.-Synthetic-Datasets-Advancing-Niche-Model-Training-for-qa/data/torch_code_base.json/step_1_torch_repo/full_codebase/_backward_state.json: 429 Resource has been exhausted (e.g. check quota).
# Processing file: /Users/moutasemhome/Human-vs.-Synthetic-Datasets-Advancing-Niche-Model-Training-for-qa/data/torch_code_base.json/step_1_torch_repo/full_codebase/find_first_use_of_broken_modules.json
# Failed to process /Users/moutasemhome/Human-vs.-Synthetic-Datasets-Advancing-Niche-Model-Training-for-qa/data/torch_code_base.json/step_1_torch_repo/full_codebase/find_first_use_of_broken_modules.json: 429 Resource has been exhausted (e.g. check quota).
# Processing file: /Users/moutasemhome/Human-vs.-Synthetic-Datasets-Advancing-Niche-Model-Training-for-qa/data/torch_code_base.json/step_1_torch_repo/full_codebase/test_gen_unboxing.json
# Failed to process /Users/moutasemhome/Human-vs.-Synthetic-Datasets-Advancing-Niche-Model-Training-for-qa/data/torch_code_base.json/step_1_torch_repo/full_codebase/test_gen_unboxing.json: 429 Resource has been exhausted (e.g. check quota).
# Processing file: /Users/moutasemhome/Human-vs.-Synthetic-Datasets-Advancing-Niche-Model-Training-for-qa/data/torch_code_base.json/step_1_torch_repo/full_codebase/repeat_benchmark.json
# Failed to process /Users/moutasemhome/Human-vs.-Synthetic-Datasets-Advancing-Niche-Model-Training-for-qa/data/torch_code_base.json/step_1_torch_repo/full_codebase/repeat_benchmark.json: 429 Resource has been exhausted (e.g. check quota).
# Processing file: /Users/moutasemhome/Human-vs.-Synthetic-Datasets-Advancing-Niche-Model-Training-for-qa/data/torch_code_base.json/step_1_torch_repo/full_codebase/virtualized.json
# Failed to process /Users/moutasemhome/Human-vs.-Synthetic-Datasets-Advancing-Niche-Model-Training-for-qa/data/torch_code_base.json/step_1_torch_repo/full_codebase/virtualized.json: 429 Resource has been exhausted (e.g. check quota).
# Processing file: /Users/moutasemhome/Human-vs.-Synthetic-Datasets-Advancing-Niche-Model-Training-for-qa/data/torch_code_base.json/step_1_torch_repo/full_codebase/test_move_constructors_to_cuda.json
# Failed to process /Users/moutasemhome/Human-vs.-Synthetic-Datasets-Advancing-Niche-Model-Training-for-qa/data/torch_code_base.json/step_1_torch_repo/full_codebase/test_move_constructors_to_cuda.json: 429 Resource has been exhausted (e.g. check quota).
# Processing file: /Users/moutasemhome/Human-vs.-Synthetic-Datasets-Advancing-Niche-Model-Training-for-qa/data/torch_code_base.json/step_1_torch_repo/full_codebase/test_fsdp_core.json
# Failed to process /Users/moutasemhome/Human-vs.-Synthetic-Datasets-Advancing-Niche-Model-Training-for-qa/data/torch_code_base.json/step_1_torch_repo/full_codebase/test_fsdp_core.json: 429 Resource has been exhausted (e.g. check quota).
# Processing file: /Users/moutasemhome/Human-vs.-Synthetic-Datasets-Advancing-Niche-Model-Training-for-qa/data/torch_code_base.json/step_1_torch_repo/full_codebase/lower_to_fbgemm.json
# Failed to process /Users/moutasemhome/Human-vs.-Synthetic-Datasets-Advancing-Niche-Model-Training-for-qa/data/torch_code_base.json/step_1_torch_repo/full_codebase/lower_to_fbgemm.json: 429 Resource has been exhausted (e.g. check quota).
# Processing file: /Users/moutasemhome/Human-vs.-Synthetic-Datasets-Advancing-Niche-Model-Training-for-qa/data/torch_code_base.json/step_1_torch_repo/full_codebase/logging_tensor.json
# Failed to process /Users/moutasemhome/Human-vs.-Synthetic-Datasets-Advancing-Niche-Model-Training-for-qa/data/torch_code_base.json/step_1_torch_repo/full_codebase/logging_tensor.json: 429 Resource has been exhausted (e.g. check quota).
# Processing file: /Users/moutasemhome/Human-vs.-Synthetic-Datasets-Advancing-Niche-Model-Training-for-qa/data/torch_code_base.json/step_1_torch_repo/full_codebase/_quantized_conversions.json
# Failed to process /Users/moutasemhome/Human-vs.-Synthetic-Datasets-Advancing-Niche-Model-Training-for-qa/data/torch_code_base.json/step_1_torch_repo/full_codebase/_quantized_conversions.json: 429 Resource has been exhausted (e.g. check quota).
# Processing file: /Users/moutasemhome/Human-vs.-Synthetic-Datasets-Advancing-Niche-Model-Training-for-qa/data/torch_code_base.json/step_1_torch_repo/full_codebase/_exporter_states.json
# Failed to process /Users/moutasemhome/Human-vs.-Synthetic-Datasets-Advancing-Niche-Model-Training-for-qa/data/torch_code_base.json/step_1_torch_repo/full_codebase/_exporter_states.json: 429 Resource has been exhausted (e.g. check quota).
# Processing file: /Users/moutasemhome/Human-vs.-Synthetic-Datasets-Advancing-Niche-Model-Training-for-qa/data/torch_code_base.json/step_1_torch_repo/full_codebase/_special_locations.json
# Failed to process /Users/moutasemhome/Human-vs.-Synthetic-Datasets-Advancing-Niche-Model-Training-for-qa/data/torch_code_base.json/step_1_torch_repo/full_codebase/_special_locations.json: 429 Resource has been exhausted (e.g. check quota).
# Processing file: /Users/moutasemhome/Human-vs.-Synthetic-Datasets-Advancing-Niche-Model-Training-for-qa/data/torch_code_base.json/step_1_torch_repo/full_codebase/vscode_settings.json
# Failed to process /Users/moutasemhome/Human-vs.-Synthetic-Datasets-Advancing-Niche-Model-Training-for-qa/data/torch_code_base.json/step_1_torch_repo/full_codebase/vscode_settings.json: 429 Resource has been exhausted (e.g. check quota).
# Processing file: /Users/moutasemhome/Human-vs.-Synthetic-Datasets-Advancing-Niche-Model-Training-for-qa/data/torch_code_base.json/step_1_torch_repo/full_codebase/module_impl_check.json
# Failed to process /Users/moutasemhome/Human-vs.-Synthetic-Datasets-Advancing-Niche-Model-Training-for-qa/data/torch_code_base.json/step_1_torch_repo/full_codebase/module_impl_check.json: 429 Resource has been exhausted (e.g. check quota).
# Processing file: /Users/moutasemhome/Human-vs.-Synthetic-Datasets-Advancing-Niche-Model-Training-for-qa/data/torch_code_base.json/step_1_torch_repo/full_codebase/gen_mobile_upgraders.json
# Failed to process /Users/moutasemhome/Human-vs.-Synthetic-Datasets-Advancing-Niche-Model-Training-for-qa/data/torch_code_base.json/step_1_torch_repo/full_codebase/gen_mobile_upgraders.json: 429 Resource has been exhausted (e.g. check quota).
# Processing file: /Users/moutasemhome/Human-vs.-Synthetic-Datasets-Advancing-Niche-Model-Training-for-qa/data/torch_code_base.json/step_1_torch_repo/full_codebase/test_eager_transforms.json
# Failed to process /Users/moutasemhome/Human-vs.-Synthetic-Datasets-Advancing-Niche-Model-Training-for-qa/data/torch_code_base.json/step_1_torch_repo/full_codebase/test_eager_transforms.json: 429 Resource has been exhausted (e.g. check quota).
# Processing file: /Users/moutasemhome/Human-vs.-Synthetic-Datasets-Advancing-Niche-Model-Training-for-qa/data/torch_code_base.json/step_1_torch_repo/full_codebase/_external_property_file_references.json
# Failed to process /Users/moutasemhome/Human-vs.-Synthetic-Datasets-Advancing-Niche-Model-Training-for-qa/data/torch_code_base.json/step_1_torch_repo/full_codebase/_external_property_file_references.json: 429 Resource has been exhausted (e.g. check quota).
# Processing file: /Users/moutasemhome/Human-vs.-Synthetic-Datasets-Advancing-Niche-Model-Training-for-qa/data/torch_code_base.json/step_1_torch_repo/full_codebase/cmake.json
# Failed to process /Users/moutasemhome/Human-vs.-Synthetic-Datasets-Advancing-Niche-Model-Training-for-qa/data/torch_code_base.json/step_1_torch_repo/full_codebase/cmake.json: 429 Resource has been exhausted (e.g. check quota).
# Processing file: /Users/moutasemhome/Human-vs.-Synthetic-Datasets-Advancing-Niche-Model-Training-for-qa/data/torch_code_base.json/step_1_torch_repo/full_codebase/as_strided_test.json
# Failed to process /Users/moutasemhome/Human-vs.-Synthetic-Datasets-Advancing-Niche-Model-Training-for-qa/data/torch_code_base.json/step_1_torch_repo/full_codebase/as_strided_test.json: 429 Resource has been exhausted (e.g. check quota).
# Processing file: /Users/moutasemhome/Human-vs.-Synthetic-Datasets-Advancing-Niche-Model-Training-for-qa/data/torch_code_base.json/step_1_torch_repo/full_codebase/mock_store_global_crossfile_inline.json
# Failed to process /Users/moutasemhome/Human-vs.-Synthetic-Datasets-Advancing-Niche-Model-Training-for-qa/data/torch_code_base.json/step_1_torch_repo/full_codebase/mock_store_global_crossfile_inline.json: 429 Resource has been exhausted (e.g. check quota).
# Processing file: /Users/moutasemhome/Human-vs.-Synthetic-Datasets-Advancing-Niche-Model-Training-for-qa/data/torch_code_base.json/step_1_torch_repo/full_codebase/tensor_setattr.json
# Failed to process /Users/moutasemhome/Human-vs.-Synthetic-Datasets-Advancing-Niche-Model-Training-for-qa/data/torch_code_base.json/step_1_torch_repo/full_codebase/tensor_setattr.json: 429 Resource has been exhausted (e.g. check quota).
# Processing file: /Users/moutasemhome/Human-vs.-Synthetic-Datasets-Advancing-Niche-Model-Training-for-qa/data/torch_code_base.json/step_1_torch_repo/full_codebase/distribution.json
# Failed to process /Users/moutasemhome/Human-vs.-Synthetic-Datasets-Advancing-Niche-Model-Training-for-qa/data/torch_code_base.json/step_1_torch_repo/full_codebase/distribution.json: 429 Resource has been exhausted (e.g. check quota).
# Processing file: /Users/moutasemhome/Human-vs.-Synthetic-Datasets-Advancing-Niche-Model-Training-for-qa/data/torch_code_base.json/step_1_torch_repo/full_codebase/triton_heuristics.json
# Failed to process /Users/moutasemhome/Human-vs.-Synthetic-Datasets-Advancing-Niche-Model-Training-for-qa/data/torch_code_base.json/step_1_torch_repo/full_codebase/triton_heuristics.json: 429 Resource has been exhausted (e.g. check quota).
# Processing file: /Users/moutasemhome/Human-vs.-Synthetic-Datasets-Advancing-Niche-Model-Training-for-qa/data/torch_code_base.json/step_1_torch_repo/full_codebase/test_batch_mm.json
# Failed to process /Users/moutasemhome/Human-vs.-Synthetic-Datasets-Advancing-Niche-Model-Training-for-qa/data/torch_code_base.json/step_1_torch_repo/full_codebase/test_batch_mm.json: 429 Resource has been exhausted (e.g. check quota).
# Processing file: /Users/moutasemhome/Human-vs.-Synthetic-Datasets-Advancing-Niche-Model-Training-for-qa/data/torch_code_base.json/step_1_torch_repo/full_codebase/patcher.json
# Failed to process /Users/moutasemhome/Human-vs.-Synthetic-Datasets-Advancing-Niche-Model-Training-for-qa/data/torch_code_base.json/step_1_torch_repo/full_codebase/patcher.json: 429 Resource has been exhausted (e.g. check quota).
# Processing file: /Users/moutasemhome/Human-vs.-Synthetic-Datasets-Advancing-Niche-Model-Training-for-qa/data/torch_code_base.json/step_1_torch_repo/full_codebase/test_trace_rules.json
# Failed to process /Users/moutasemhome/Human-vs.-Synthetic-Datasets-Advancing-Niche-Model-Training-for-qa/data/torch_code_base.json/step_1_torch_repo/full_codebase/test_trace_rules.json: 429 Resource has been exhausted (e.g. check quota).
# Processing file: /Users/moutasemhome/Human-vs.-Synthetic-Datasets-Advancing-Niche-Model-Training-for-qa/data/torch_code_base.json/step_1_torch_repo/full_codebase/_jit_internal.json
# Failed to process /Users/moutasemhome/Human-vs.-Synthetic-Datasets-Advancing-Niche-Model-Training-for-qa/data/torch_code_base.json/step_1_torch_repo/full_codebase/_jit_internal.json: 429 Resource has been exhausted (e.g. check quota).
# Processing file: /Users/moutasemhome/Human-vs.-Synthetic-Datasets-Advancing-Niche-Model-Training-for-qa/data/torch_code_base.json/step_1_torch_repo/full_codebase/resnet_memory_profiler.json
# Failed to process /Users/moutasemhome/Human-vs.-Synthetic-Datasets-Advancing-Niche-Model-Training-for-qa/data/torch_code_base.json/step_1_torch_repo/full_codebase/resnet_memory_profiler.json: 429 Resource has been exhausted (e.g. check quota).
# Processing file: /Users/moutasemhome/Human-vs.-Synthetic-Datasets-Advancing-Niche-Model-Training-for-qa/data/torch_code_base.json/step_1_torch_repo/full_codebase/summary.json
# Failed to process /Users/moutasemhome/Human-vs.-Synthetic-Datasets-Advancing-Niche-Model-Training-for-qa/data/torch_code_base.json/step_1_torch_repo/full_codebase/summary.json: 429 Resource has been exhausted (e.g. check quota).
# Processing file: /Users/moutasemhome/Human-vs.-Synthetic-Datasets-Advancing-Niche-Model-Training-for-qa/data/torch_code_base.json/step_1_torch_repo/full_codebase/test_efficient_conv_bn_eval.json
# Failed to process /Users/moutasemhome/Human-vs.-Synthetic-Datasets-Advancing-Niche-Model-Training-for-qa/data/torch_code_base.json/step_1_torch_repo/full_codebase/test_efficient_conv_bn_eval.json: 429 Resource has been exhausted (e.g. check quota).
# Processing file: /Users/moutasemhome/Human-vs.-Synthetic-Datasets-Advancing-Niche-Model-Training-for-qa/data/torch_code_base.json/step_1_torch_repo/full_codebase/fake_script_class.json
# Failed to process /Users/moutasemhome/Human-vs.-Synthetic-Datasets-Advancing-Niche-Model-Training-for-qa/data/torch_code_base.json/step_1_torch_repo/full_codebase/fake_script_class.json: 429 Resource has been exhausted (e.g. check quota).
# Processing file: /Users/moutasemhome/Human-vs.-Synthetic-Datasets-Advancing-Niche-Model-Training-for-qa/data/torch_code_base.json/step_1_torch_repo/full_codebase/base_sparsifier.json
# Failed to process /Users/moutasemhome/Human-vs.-Synthetic-Datasets-Advancing-Niche-Model-Training-for-qa/data/torch_code_base.json/step_1_torch_repo/full_codebase/base_sparsifier.json: 429 Resource has been exhausted (e.g. check quota).
# Processing file: /Users/moutasemhome/Human-vs.-Synthetic-Datasets-Advancing-Niche-Model-Training-for-qa/data/torch_code_base.json/step_1_torch_repo/full_codebase/broadcast.json
# Failed to process /Users/moutasemhome/Human-vs.-Synthetic-Datasets-Advancing-Niche-Model-Training-for-qa/data/torch_code_base.json/step_1_torch_repo/full_codebase/broadcast.json: 429 Resource has been exhausted (e.g. check quota).
# Processing file: /Users/moutasemhome/Human-vs.-Synthetic-Datasets-Advancing-Niche-Model-Training-for-qa/data/torch_code_base.json/step_1_torch_repo/full_codebase/half_normal.json
# Failed to process /Users/moutasemhome/Human-vs.-Synthetic-Datasets-Advancing-Niche-Model-Training-for-qa/data/torch_code_base.json/step_1_torch_repo/full_codebase/half_normal.json: 429 Resource has been exhausted (e.g. check quota).
# Processing file: /Users/moutasemhome/Human-vs.-Synthetic-Datasets-Advancing-Niche-Model-Training-for-qa/data/torch_code_base.json/step_1_torch_repo/full_codebase/test_ignorable_args.json
# ...
# /Users/moutasemhome/Human-vs.-Synthetic-Datasets-Advancing-Niche-Model-Training-for-qa/data/torch_code_base.json/step_1_torch_repo/full_codebase/test_checkpoint.json: 429 Resource has been exhausted (e.g. check quota).
# /Users/moutasemhome/Human-vs.-Synthetic-Datasets-Advancing-Niche-Model-Training-for-qa/data/torch_code_base.json/step_1_torch_repo/full_codebase/rocm_template_buffer.json: 429 Resource has been exhausted (e.g. check quota).
# /Users/moutasemhome/Human-vs.-Synthetic-Datasets-Advancing-Niche-Model-Training-for-qa/data/torch_code_base.json/step_1_torch_repo/full_codebase/test_convert_activation.json: 429 Resource has been exhausted (e.g. check quota).
# /Users/moutasemhome/Human-vs.-Synthetic-Datasets-Advancing-Niche-Model-Training-for-qa/data/torch_code_base.json/step_1_torch_repo/full_codebase/test_torch.json: 429 Resource has been exhausted (e.g. check quota).
# /Users/moutasemhome/Human-vs.-Synthetic-Datasets-Advancing-Niche-Model-Training-for-qa/data/torch_code_base.json/step_1_torch_repo/full_codebase/_attachment.json: 429 Resource has been exhausted (e.g. check quota).
# /Users/moutasemhome/Human-vs.-Synthetic-Datasets-Advancing-Niche-Model-Training-for-qa/data/torch_code_base.json/step_1_torch_repo/full_codebase/test_fully_shard_extensions.json: 429 Resource has been exhausted (e.g. check quota).
# /Users/moutasemhome/Human-vs.-Synthetic-Datasets-Advancing-Niche-Model-Training-for-qa/data/torch_code_base.json/step_1_torch_repo/full_codebase/operator_support.json: 429 Resource has been exhausted (e.g. check quota).
# /Users/moutasemhome/Human-vs.-Synthetic-Datasets-Advancing-Niche-Model-Training-for-qa/data/torch_code_base.json/step_1_torch_repo/full_codebase/test_jit.json: 429 Resource has been exhausted (e.g. check quota).
# /Users/moutasemhome/Human-vs.-Synthetic-Datasets-Advancing-Niche-Model-Training-for-qa/data/torch_code_base.json/step_1_torch_repo/full_codebase/test_launcher.json: 500 An internal error has occurred. Please retry or report in https://developers.generativeai.google/guide/troubleshooting
# /Users/moutasemhome/Human-vs.-Synthetic-Datasets-Advancing-Niche-Model-Training-for-qa/data/torch_code_base.json/step_1_torch_repo/full_codebase/remote_module_template.json: 500 An internal error has occurred. Please retry or report in https://developers.generativeai.google/guide/troubleshooting
# /Users/moutasemhome/Human-vs.-Synthetic-Datasets-Advancing-Niche-Model-Training-for-qa/data/torch_code_base.json/step_1_torch_repo/full_codebase/test_c10d_gloo.json: 429 Resource has been exhausted (e.g. check quota).
# /Users/moutasemhome/Human-vs.-Synthetic-Datasets-Advancing-Niche-Model-Training-for-qa/data/torch_code_base.json/step_1_torch_repo/full_codebase/test_device_analysis.json: 429 Resource has been exhausted (e.g. check quota).
# /Users/moutasemhome/Human-vs.-Synthetic-Datasets-Advancing-Niche-Model-Training-for-qa/data/torch_code_base.json/step_1_torch_repo/full_codebase/functional_adam.json: 429 Resource has been exhausted (e.g. check quota).
# /Users/moutasemhome/Human-vs.-Synthetic-Datasets-Advancing-Niche-Model-Training-for-qa/data/torch_code_base.json/step_1_torch_repo/full_codebase/test_sparse.json: 429 Resource has been exhausted (e.g. check quota).
# /Users/moutasemhome/Human-vs.-Synthetic-Datasets-Advancing-Niche-Model-Training-for-qa/data/torch_code_base.json/step_1_torch_repo/full_codebase/argparse_util.json: 429 Resource has been exhausted (e.g. check quota).
# /Users/moutasemhome/Human-vs.-Synthetic-Datasets-Advancing-Niche-Model-Training-for-qa/data/torch_code_base.json/step_1_torch_repo/full_codebase/test_embedding_ops.json: 429 Resource has been exhausted (e.g. check quota).
# /Users/moutasemhome/Human-vs.-Synthetic-Datasets-Advancing-Niche-Model-Training-for-qa/data/torch_code_base.json/step_1_torch_repo/full_codebase/coreml_backend.json: 429 Resource has been exhausted (e.g. check quota).
# /Users/moutasemhome/Human-vs.-Synthetic-Datasets-Advancing-Niche-Model-Training-for-qa/data/torch_code_base.json/step_1_torch_repo/full_codebase/decorators.json: 429 Resource has been exhausted (e.g. check quota).
# /Users/moutasemhome/Human-vs.-Synthetic-Datasets-Advancing-Niche-Model-Training-for-qa/data/torch_code_base.json/step_1_torch_repo/full_codebase/previously_failed_in_pr.json: 429 Resource has been exhausted (e.g. check quota).
# /Users/moutasemhome/Human-vs.-Synthetic-Datasets-Advancing-Niche-Model-Training-for-qa/data/torch_code_base.json/step_1_torch_repo/full_codebase/test_tensorexpr.json: 429 Resource has been exhausted (e.g. check quota).
# /Users/moutasemhome/Human-vs.-Synthetic-Datasets-Advancing-Niche-Model-Training-for-qa/data/torch_code_base.json/step_1_torch_repo/full_codebase/nn_module.json: 429 Resource has been exhausted (e.g. check quota).
# /Users/moutasemhome/Human-vs.-Synthetic-Datasets-Advancing-Niche-Model-Training-for-qa/data/torch_code_base.json/step_1_torch_repo/full_codebase/test_proxy_tensor.json: 429 Resource has been exhausted (e.g. check quota).
# /Users/moutasemhome/Human-vs.-Synthetic-Datasets-Advancing-Niche-Model-Training-for-qa/data/torch_code_base.json/step_1_torch_repo/full_codebase/dataset.json: 429 Resource has been exhausted (e.g. check quota).
# /Users/moutasemhome/Human-vs.-Synthetic-Datasets-Advancing-Niche-Model-Training-for-qa/data/torch_code_base.json/step_1_torch_repo/full_codebase/debug_utils.json: 429 Resource has been exhausted (e.g. check quota).
# /Users/moutasemhome/Human-vs.-Synthetic-Datasets-Advancing-Niche-Model-Training-for-qa/data/torch_code_base.json/step_1_torch_repo/full_codebase/coverage_record.json: 429 Resource has been exhausted (e.g. check quota).
# /Users/moutasemhome/Human-vs.-Synthetic-Datasets-Advancing-Niche-Model-Training-for-qa/data/torch_code_base.json/step_1_torch_repo/full_codebase/meta.json: 429 Resource has been exhausted (e.g. check quota).
# /Users/moutasemhome/Human-vs.-Synthetic-Datasets-Advancing-Niche-Model-Training-for-qa/data/torch_code_base.json/step_1_torch_repo/full_codebase/dump_all_function_schemas.json: 429 Resource has been exhausted (e.g. check quota).
# /Users/moutasemhome/Human-vs.-Synthetic-Datasets-Advancing-Niche-Model-Training-for-qa/data/torch_code_base.json/step_1_torch_repo/full_codebase/_ordered_set.json: 429 Resource has been exhausted (e.g. check quota).
# /Users/moutasemhome/Human-vs.-Synthetic-Datasets-Advancing-Niche-Model-Training-for-qa/data/torch_code_base.json/step_1_torch_repo/full_codebase/device_op_overrides.json: 429 Resource has been exhausted (e.g. check quota).
# /Users/moutasemhome/Human-vs.-Synthetic-Datasets-Advancing-Niche-Model-Training-for-qa/data/torch_code_base.json/step_1_torch_repo/full_codebase/_multiformat_message_string.json: 429 Resource has been exhausted (e.g. check quota).
# /Users/moutasemhome/Human-vs.-Synthetic-Datasets-Advancing-Niche-Model-Training-for-qa/data/torch_code_base.json/step_1_torch_repo/full_codebase/faulty_rpc_agent_test_fixture.json: 429 Resource has been exhausted (e.g. check quota).
# /Users/moutasemhome/Human-vs.-Synthetic-Datasets-Advancing-Niche-Model-Training-for-qa/data/torch_code_base.json/step_1_torch_repo/full_codebase/test_matrix_ops.json: 429 Resource has been exhausted (e.g. check quota).
# /Users/moutasemhome/Human-vs.-Synthetic-Datasets-Advancing-Niche-Model-Training-for-qa/data/torch_code_base.json/step_1_torch_repo/full_codebase/_flags.json: 429 Resource has been exhausted (e.g. check quota).
# /Users/moutasemhome/Human-vs.-Synthetic-Datasets-Advancing-Niche-Model-Training-for-qa/data/torch_code_base.json/step_1_torch_repo/full_codebase/executorch_call_delegate.json: 429 Resource has been exhausted (e.g. check quota).
# /Users/moutasemhome/Human-vs.-Synthetic-Datasets-Advancing-Niche-Model-Training-for-qa/data/torch_code_base.json/step_1_torch_repo/full_codebase/autotune_process.json: 429 Resource has been exhausted (e.g. check quota).
# /Users/moutasemhome/Human-vs.-Synthetic-Datasets-Advancing-Niche-Model-Training-for-qa/data/torch_code_base.json/step_1_torch_repo/full_codebase/op_benchmark.json: 429 Resource has been exhausted (e.g. check quota).
# /Users/moutasemhome/Human-vs.-Synthetic-Datasets-Advancing-Niche-Model-Training-for-qa/data/torch_code_base.json/step_1_torch_repo/full_codebase/tensor_ops.json: 429 Resource has been exhausted (e.g. check quota).
# /Users/moutasemhome/Human-vs.-Synthetic-Datasets-Advancing-Niche-Model-Training-for-qa/data/torch_code_base.json/step_1_torch_repo/full_codebase/splitter_base.json: 429 Resource has been exhausted (e.g. check quota).
# /Users/moutasemhome/Human-vs.-Synthetic-Datasets-Advancing-Niche-Model-Training-for-qa/data/torch_code_base.json/step_1_torch_repo/full_codebase/test_cudagraphs_expandable_segments.json: 429 Resource has been exhausted (e.g. check quota).
# /Users/moutasemhome/Human-vs.-Synthetic-Datasets-Advancing-Niche-Model-Training-for-qa/data/torch_code_base.json/step_1_torch_repo/full_codebase/test_sharded_tensor.json: 429 Resource has been exhausted (e.g. check quota).
# /Users/moutasemhome/Human-vs.-Synthetic-Datasets-Advancing-Niche-Model-Training-for-qa/data/torch_code_base.json/step_1_torch_repo/full_codebase/test_inductor_freezing.json: 429 Resource has been exhausted (e.g. check quota).
# /Users/moutasemhome/Human-vs.-Synthetic-Datasets-Advancing-Niche-Model-Training-for-qa/data/torch_code_base.json/step_1_torch_repo/full_codebase/weight_utils.json: 429 Resource has been exhausted (e.g. check quota).
# /Users/moutasemhome/Human-vs.-Synthetic-Datasets-Advancing-Niche-Model-Training-for-qa/data/torch_code_base.json/step_1_torch_repo/full_codebase/gen.json: 429 Resource has been exhausted (e.g. check quota).
# /Users/moutasemhome/Human-vs.-Synthetic-Datasets-Advancing-Niche-Model-Training-for-qa/data/torch_code_base.json/step_1_torch_repo/full_codebase/test_fx_passes_pre_grad.json: 429 Resource has been exhausted (e.g. check quota).
# /Users/moutasemhome/Human-vs.-Synthetic-Datasets-Advancing-Niche-Model-Training-for-qa/data/torch_code_base.json/step_1_torch_repo/full_codebase/qconv_test.json: 429 Resource has been exhausted (e.g. check quota).
# /Users/moutasemhome/Human-vs.-Synthetic-Datasets-Advancing-Niche-Model-Training-for-qa/data/torch_code_base.json/step_1_torch_repo/full_codebase/_conversions.json: 429 Resource has been exhausted (e.g. check quota).
# /Users/moutasemhome/Human-vs.-Synthetic-Datasets-Advancing-Niche-Model-Training-for-qa/data/torch_code_base.json/step_1_torch_repo/full_codebase/test_pipe.json: 429 Resource has been exhausted (e.g. check quota).
# /Users/moutasemhome/Human-vs.-Synthetic-Datasets-Advancing-Niche-Model-Training-for-qa/data/torch_code_base.json/step_1_torch_repo/full_codebase/chunk_sharding_spec.json: 429 Resource has been exhausted (e.g. check quota).
# /Users/moutasemhome/Human-vs.-Synthetic-Datasets-Advancing-Niche-Model-Training-for-qa/data/torch_code_base.json/step_1_torch_repo/full_codebase/test_fuse_eager.json: 429 Resource has been exhausted (e.g. check quota).
# /Users/moutasemhome/Human-vs.-Synthetic-Datasets-Advancing-Niche-Model-Training-for-qa/data/torch_code_base.json/step_1_torch_repo/full_codebase/_importlib.json: 429 Resource has been exhausted (e.g. check quota).
# /Users/moutasemhome/Human-vs.-Synthetic-Datasets-Advancing-Niche-Model-Training-for-qa/data/torch_code_base.json/step_1_torch_repo/full_codebase/dist_util.json: 429 Resource has been exhausted (e.g. check quota).
# /Users/moutasemhome/Human-vs.-Synthetic-Datasets-Advancing-Niche-Model-Training-for-qa/data/torch_code_base.json/step_1_torch_repo/full_codebase/cuda_cpp_scheduling.json: 429 Resource has been exhausted (e.g. check quota).
# /Users/moutasemhome/Human-vs.-Synthetic-Datasets-Advancing-Niche-Model-Training-for-qa/data/torch_code_base.json/step_1_torch_repo/full_codebase/decompositions.json: 429 Resource has been exhausted (e.g. check quota).
# /Users/moutasemhome/Human-vs.-Synthetic-Datasets-Advancing-Niche-Model-Training-for-qa/data/torch_code_base.json/step_1_torch_repo/full_codebase/callable.json: 429 Resource has been exhausted (e.g. check quota).
# /Users/moutasemhome/Human-vs.-Synthetic-Datasets-Advancing-Niche-Model-Training-for-qa/data/torch_code_base.json/step_1_torch_repo/full_codebase/_getlimits.json: 429 Resource has been exhausted (e.g. check quota).
# /Users/moutasemhome/Human-vs.-Synthetic-Datasets-Advancing-Niche-Model-Training-for-qa/data/torch_code_base.json/step_1_torch_repo/full_codebase/gen_selected_mobile_ops_header.json: 429 Resource has been exhausted (e.g. check quota).
# /Users/moutasemhome/Human-vs.-Synthetic-Datasets-Advancing-Niche-Model-Training-for-qa/data/torch_code_base.json/step_1_torch_repo/full_codebase/tracer.json: 429 Resource has been exhausted (e.g. check quota).
# /Users/moutasemhome/Human-vs.-Synthetic-Datasets-Advancing-Niche-Model-Training-for-qa/data/torch_code_base.json/step_1_torch_repo/full_codebase/overheads.json: 429 Resource has been exhausted (e.g. check quota).
# /Users/moutasemhome/Human-vs.-Synthetic-Datasets-Advancing-Niche-Model-Training-for-qa/data/torch_code_base.json/step_1_torch_repo/full_codebase/check_kernel_launches.json: 429 Resource has been exhausted (e.g. check quota).
# /Users/moutasemhome/Human-vs.-Synthetic-Datasets-Advancing-Niche-Model-Training-for-qa/data/torch_code_base.json/step_1_torch_repo/full_codebase/readability.json: 429 Resource has been exhausted (e.g. check quota).
# /Users/moutasemhome/Human-vs.-Synthetic-Datasets-Advancing-Niche-Model-Training-for-qa/data/torch_code_base.json/step_1_torch_repo/full_codebase/rendezvous.json: 429 Resource has been exhausted (e.g. check quota).
# /Users/moutasemhome/Human-vs.-Synthetic-Datasets-Advancing-Niche-Model-Training-for-qa/data/torch_code_base.json/step_1_torch_repo/full_codebase/_cpp_extension_versioner.json: 429 Resource has been exhausted (e.g. check quota).
# /Users/moutasemhome/Human-vs.-Synthetic-Datasets-Advancing-Niche-Model-Training-for-qa/data/torch_code_base.json/step_1_torch_repo/full_codebase/find_file_dependencies.json: 429 Resource has been exhausted (e.g. check quota).
# /Users/moutasemhome/Human-vs.-Synthetic-Datasets-Advancing-Niche-Model-Training-for-qa/data/torch_code_base.json/step_1_torch_repo/full_codebase/inductor_bmm.json: 429 Resource has been exhausted (e.g. check quota).
# /Users/moutasemhome/Human-vs.-Synthetic-Datasets-Advancing-Niche-Model-Training-for-qa/data/torch_code_base.json/step_1_torch_repo/full_codebase/join.json: 429 Resource has been exhausted (e.g. check quota).
# /Users/moutasemhome/Human-vs.-Synthetic-Datasets-Advancing-Niche-Model-Training-for-qa/data/torch_code_base.json/step_1_torch_repo/full_codebase/test_tp_random_state.json: 429 Resource has been exhausted (e.g. check quota).
# /Users/moutasemhome/Human-vs.-Synthetic-Datasets-Advancing-Niche-Model-Training-for-qa/data/torch_code_base.json/step_1_torch_repo/full_codebase/functional_call.json: 429 Resource has been exhausted (e.g. check quota).
# /Users/moutasemhome/Human-vs.-Synthetic-Datasets-Advancing-Niche-Model-Training-for-qa/data/torch_code_base.json/step_1_torch_repo/full_codebase/efficient_conv_bn_eval.json: 429 Resource has been exhausted (e.g. check quota).
# /Users/moutasemhome/Human-vs.-Synthetic-Datasets-Advancing-Niche-Model-Training-for-qa/data/torch_code_base.json/step_1_torch_repo/full_codebase/visualize_sharding_example.json: 429 Resource has been exhausted (e.g. check quota).
# /Users/moutasemhome/Human-vs.-Synthetic-Datasets-Advancing-Niche-Model-Training-for-qa/data/torch_code_base.json/step_1_torch_repo/full_codebase/test_fully_shard_state_dict.json: 429 Resource has been exhausted (e.g. check quota).
# /Users/moutasemhome/Human-vs.-Synthetic-Datasets-Advancing-Niche-Model-Training-for-qa/data/torch_code_base.json/step_1_torch_repo/full_codebase/_type_utils.json: 429 Resource has been exhausted (e.g. check quota).
# Total files processed: 213
# Files left to process: 2459
# CPU times: user 8.79 s, sys: 5.05 s, total: 13.8 s
# Wall time: 1h 10min 59s
